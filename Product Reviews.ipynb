# %%
import pandas as pd
import numpy as np
from selenium import webdriver
import time
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import NoSuchElementException

# %%
driver = webdriver.Chrome(r"C:\Users\OWNER\Downloads\chromedriver.exe")

driver.maximize_window()

driver.get('https://www.amazon.in/Redmi-Activ-Coral-Green-Storage/dp/B09GFLFMPS/ref=lp_1389401031_1_10')

time.sleep(3)

#Going into the reviews page

driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[5]/div[38]/div/div/div[2]/div/div[2]/span[3]/div/div/div[5]/div[2]/a").click()

# %%
URLS = []

driver.find_element_by_xpath("//a[@class='a-link-normal 5star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

# %%
#For 4 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 4star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

# %%
#For 3 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 3star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

# %%
#For 2 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 2star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 1 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 1star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

# %%
Comments = []
Ratings = []

for i in URLS:
    driver.get(i)
    time.sleep(2)
    
    #comments
    c = driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']")
    Comments.append(c.text)
    
    #Ratings
    r = driver.find_element_by_xpath("//span[@class='a-icon-alt']").get_attribute('innerHTML').split(' ')[0]
    Ratings.append(r)

# %%
#For other Product
driver.get('https://www.amazon.in/OnePlus-Mirror-Black-128GB-Storage/dp/B085J1PFYB')
time.sleep(5)

#Going into the reviews page

driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[5]/div[38]/div/div/div[2]/div/div[2]/span[3]/div/div/div[5]/div[2]/a").click()

# %%
URLS = []

driver.find_element_by_xpath("//a[@class='a-link-normal 5star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

#For 4 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 4star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 3 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 3star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 2 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 2star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 1 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 1star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

# %%
for i in URLS:
    driver.get(i)
    time.sleep(2)
    
    #comments
    c = driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']")
    Comments.append(c.text)
    
    #Ratings
    r = driver.find_element_by_xpath("//span[@class='a-icon-alt']").get_attribute('innerHTML').split(' ')[0]
    Ratings.append(r)

# %%
#For other Product
driver.get('https://www.amazon.in/Sony-Bravia-inches-Smart-KDL-43W6603/dp/B086CGNG4T/ref=lp_5903486031_1_4')
time.sleep(5)

#Going into the reviews page
driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[5]/div[26]/div/div[2]/div/div[2]/span[3]/div/div/div[5]/div[2]/a").click()

# %%
URLS = []

driver.find_element_by_xpath("//a[@class='a-link-normal 5star']").click()
time.sleep(2)

for i in range(1,3):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

#For 4 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 4star']").click()
time.sleep(2)

for i in range(1,3):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 3 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 3star']").click()
time.sleep(2)

for i in range(1,3):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 2 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 2star']").click()
time.sleep(2)

for i in range(1,3):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 1 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 1star']").click()
time.sleep(2)

for i in range(1,3):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

# %%
for i in URLS:
    driver.get(i)
    time.sleep(2)
    
    #comments
    c = driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']")
    Comments.append(c.text)
    
    #Ratings
    r = driver.find_element_by_xpath("//span[@class='a-icon-alt']").get_attribute('innerHTML').split(' ')[0]
    Ratings.append(r)

# %%
#For other Product
driver.get('https://www.amazon.in/Mi-inches-Ready-Android-Black/dp/B084872DQY/ref=sxin_14?asc_contentid=amzn1.osa.9cc50813-3dca-4795-aca3-9a68678aa304.A21TJRUUN4KGV.en_IN&asc_contenttype=article&ascsubtag=amzn1.osa.9cc50813-3dca-4795-aca3-9a68678aa304.A21TJRUUN4KGV.en_IN&creativeASIN=B084872DQY&cv_ct_cx=tv&cv_ct_id=amzn1.osa.9cc50813-3dca-4795-aca3-9a68678aa304.A21TJRUUN4KGV.en_IN&cv_ct_pg=search&cv_ct_we=asin&cv_ct_wn=osp-single-source-earns-comm&keywords=tv&linkCode=oas&pd_rd_i=B084872DQY&pd_rd_r=dd681ba6-23dd-4f7f-b2b4-97252e870f5a&pd_rd_w=qWJii&pd_rd_wg=HCMq0&pf_rd_p=0e89a72f-7500-4160-954f-faff18efeda5&pf_rd_r=QRS2T6MET89ACRP8DE4C&qid=1636970595&sr=1-1-61f4c597-7a45-4a97-bd75-c52903f8ee93&tag=gadgetsnow03-21')
time.sleep(6)

#Going into the reviews page
driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[5]/div[38]/div/div/div[2]/div/div[2]/span[3]/div/div/div[5]/div[2]/a").click()

# %%
URLS = []

driver.find_element_by_xpath("//a[@class='a-link-normal 5star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

#For 4 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 4star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 3 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 3star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 2 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 2star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 1 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 1star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

# %%
for i in URLS:
    driver.get(i)
    time.sleep(2)
    
    #comments
    c = driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']")
    Comments.append(c.text)
    
    #Ratings
    r = driver.find_element_by_xpath("//span[@class='a-icon-alt']").get_attribute('innerHTML').split(' ')[0]
    Ratings.append(r)

# %%
driver = webdriver.Chrome(r"C:\Users\OWNER\Downloads\chromedriver.exe")

driver.maximize_window()

# %%
#For other Product
driver.get('https://www.amazon.in/Samsung-Fully-Automatic-WA65A4002VS-TL-Technology/dp/B08GY3PZQF/ref=sr_1_10?keywords=washing+machine&qid=1637069116&sr=8-10')
time.sleep(6)

#Going into the reviews page
driver.find_element_by_xpath("//a[@class='a-link-emphasis a-text-bold']").click()

# %%
URLS = []

driver.find_element_by_xpath("//a[@class='a-link-normal 5star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

#For 4 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 4star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 3 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 3star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 2 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 2star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 1 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 1star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

# %%
for i in URLS:
    driver.get(i)
    time.sleep(2)
    
    #comments
    c = driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']")
    Comments.append(c.text)
    
    #Ratings
    r = driver.find_element_by_xpath("//span[@class='a-icon-alt']").get_attribute('innerHTML').split(' ')[0]
    Ratings.append(r)

# %%
#For other Product
driver.get('https://www.amazon.in/TP-Link-Wireless-Security-Tapo-C200/dp/B07XLML2YS/ref=zg_bs_1388977031_11?_encoding=UTF8&refRID=9SMZKZQP4XBE7EHE4DE9&th=1')
time.sleep(6)

#Going into the reviews page
driver.find_element_by_xpath("//a[@class='a-link-emphasis a-text-bold']").click()

# %%
URLS = []

driver.find_element_by_xpath("//a[@class='a-link-normal 5star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

#For 4 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 4star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 3 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 3star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 2 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 2star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 1 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 1star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

# %%
for i in URLS:
    driver.get(i)
    time.sleep(2)
    
    #comments
    c = driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']")
    Comments.append(c.text)
    
    #Ratings
    r = driver.find_element_by_xpath("//span[@class='a-icon-alt']").get_attribute('innerHTML').split(' ')[0]
    Ratings.append(r)

# %%
driver = webdriver.Chrome(r"C:\Users\OWNER\Downloads\chromedriver.exe")

driver.maximize_window()

# %%
#For other Product
driver.get('https://www.amazon.in/boAt-Smartwatch-Multiple-Monitoring-Resistance/dp/B096VF5YYF/ref=zg_bs_electronics_12?_encoding=UTF8&refRID=TQA49ME0EKA0GXQ9X28V&th=1')
time.sleep(6)

#Going into the reviews page
driver.find_element_by_xpath("//a[@class='a-link-emphasis a-text-bold']").click()

# %%
URLS = []

driver.find_element_by_xpath("//a[@class='a-link-normal 5star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

#For 4 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 4star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 3 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 3star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 2 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 2star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 1 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 1star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

# %%
for i in URLS:
    driver.get(i)
    time.sleep(2)
    
    #comments
    c = driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']")
    Comments.append(c.text)
    
    #Ratings
    r = driver.find_element_by_xpath("//span[@class='a-icon-alt']").get_attribute('innerHTML').split(' ')[0]
    Ratings.append(r)

# %%
#For other Product
driver.get('https://www.amazon.in/SanDisk-Cruzer-Blade-Flash-Drive/dp/B005FYNT3G/ref=zg_bs_electronics_21?_encoding=UTF8&refRID=TQA49ME0EKA0GXQ9X28V&th=1')
time.sleep(6)

#Going into the reviews page
driver.find_element_by_xpath("//a[@class='a-link-emphasis a-text-bold']").click()

# %%
URLS = []

driver.find_element_by_xpath("//a[@class='a-link-normal 5star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

#For 4 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 4star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 3 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 3star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 2 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 2star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 1 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 1star']").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

# %%
for i in URLS:
    driver.get(i)
    time.sleep(2)
    
    #comments
    c = driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']")
    Comments.append(c.text)
    
    #Ratings
    r = driver.find_element_by_xpath("//span[@class='a-icon-alt']").get_attribute('innerHTML').split(' ')[0]
    Ratings.append(r)

# %%
#For other Product
driver.get('https://www.amazon.in/Echo-Dot-3rd-Gen/dp/B07PFFMP9P/ref=zg_bs_electronics_59?_encoding=UTF8&psc=1&refRID=JJ15ZF9TYR5M002MB3R7')
time.sleep(6)

#Going into the reviews page
driver.find_element_by_xpath("//a[@class='a-link-emphasis a-text-bold']").click()

# %%
URLS = []

driver.find_element_by_xpath("//a[@class='a-link-normal 5star']").click()
time.sleep(2)

for i in range(1,5):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

#For 4 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 4star']").click()
time.sleep(2)

for i in range(1,5):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 3 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 3star']").click()
time.sleep(2)

for i in range(1,5):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 2 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 2star']").click()
time.sleep(2)

for i in range(1,5):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 1 Stars rating

driver.find_element_by_xpath("//a[@class='a-link-normal 1star']").click()
time.sleep(2)

for i in range(1,5):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

# %%
for i in URLS:
    driver.get(i)
    time.sleep(2)
    
    #comments
    c = driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']")
    Comments.append(c.text)
    
    #Ratings
    r = driver.find_element_by_xpath("//span[@class='a-icon-alt']").get_attribute('innerHTML').split(' ')[0]
    Ratings.append(r)

# %%
data = list(zip(Comments, Ratings))

# %%
pr = pd.DataFrame(data = data, columns = ['Comments', 'Ratings'])
pr.to_csv('Comment Ratings.csv')

# %%
driver.close()
