# %%
# !pip install selenium
import pandas as pd
import numpy as np
from selenium import webdriver
import time
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import NoSuchElementException

# %%
driver = webdriver.Chrome(r"C:\Users\OWNER\Downloads\chromedriver.exe")

driver.get('https://www.amazon.in')

time.sleep(4)

# For going into the mobiles section

driver.find_element_by_xpath('/html/body/div[1]/header/div/div[5]/div[2]/div/div/a[1]').click()

# for getting into the details of specific mobile

driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[2]/div[1]/div[5]/div/div/div/div/div/div[2]/div/ol/li[1]/div/div[1]/a/img').click()

#Going into the reviews page

driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[5]/div[38]/div/div/div[2]/div/div[2]/span[3]/div/div/div[5]/div[2]/a").click()

# %%
# For 5 Stars
driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[1]/td[1]/span[1]/a').click()

# %%
URLS = []


for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

# %%
#For 4 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[2]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

# %%
#For 3 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[3]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

# %%
#For 2 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[4]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 1 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[5]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URLS.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

# %%
Comments = []
Ratings = []

for i in URLS:
    driver.get(i)
    time.sleep(2)
    
    #comments
    c = driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']")
    Comments.append(c.text)
    
    #Ratings
    r = driver.find_element_by_xpath("//span[@class='a-size-medium a-color-base']").get_attribute('innerHTML').split(' ')[0]
    Ratings.append(r)

# %%
driver = webdriver.Chrome(r"C:\Users\OWNER\Downloads\chromedriver.exe")

# %%
#For other Product
driver.get('https://www.amazon.in')
time.sleep(5)

driver.find_element_by_xpath('/html/body/div[1]/header/div/div[5]/div[2]/div/div/a[3]').click()
time.sleep(2)

# %%
# for getting into the details of specific mobile

driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[2]/div[2]/div/div/div[1]/ul/li[10]/span/a').click()

# %%
# for getting into the details of specific mobile

driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[2]/div[1]/div[5]/div/div/div/div/div/div[2]/div/ol/li[1]/div/a/span/span[2]').click()


#Going into the reviews page

driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[5]/div[38]/div/div/div[2]/div/div[2]/span[3]/div/div/div[5]/div[2]/a").click()

# %%
URL1 = []

# For 5 Stars
driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[1]/td[1]/span[1]/a').click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL1.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

#For 4 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[2]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL1.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

#For 3 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[3]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL1.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 2 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[4]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL1.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 1 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[5]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL1.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

# %%
for i in URL1:
    driver.get(i)
    time.sleep(2)
    
    #comments
    c = driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']")
    Comments.append(c.text)
    
    #Ratings
    r = driver.find_element_by_xpath("//span[@class='a-size-medium a-color-base']").get_attribute('innerHTML').split(' ')[0]
    Ratings.append(r)

# %%
#For other Product
driver.get('https://www.amazon.in/dp/B09F9YQQ7B/ref=QANavsony11CTA_en_IN_1?pf_rd_r=MENP2RVTZBJPA9WR6VH6&pf_rd_p=553370f4-da5d-40c6-885d-a96730db52bc&pf_rd_m=A1VBAL9TL5WCBF&pf_rd_s=merchandised-search-3&pf_rd_t=&pf_rd_i=1389396031&th=1')
time.sleep(5)

#Going into the reviews page
driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[5]/div[38]/div/div/div[2]/div/div[2]/span[3]/div/div/div[5]/div[2]/a").click()

# %%
URL2 = []

# For 5 Stars
driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[1]/td[1]/span[1]/a').click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

#For 4 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[2]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

#For 3 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[3]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 2 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[4]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 1 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[5]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

# %%
for i in URL2:
    driver.get(i)
    time.sleep(2)
    
    #comments
    c = driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']")
    Comments.append(c.text)
    
    #Ratings
    r = driver.find_element_by_xpath("//span[@class='a-size-medium a-color-base']").get_attribute('innerHTML').split(' ')[0]
    Ratings.append(r)

# %%
#For other Product
driver.get('https://www.amazon.in/Sony-Bravia-inches-Smart-KDL-43W6603/dp/B086CGNG4T/ref=lp_5903486031_1_4')
time.sleep(5)

#Going into the reviews page
driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[5]/div[26]/div/div[2]/div/div[2]/span[3]/div/div/div[5]/div[2]/a").click()

# %%
URL2 = []

# For 5 Stars
driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[1]/td[1]/span[1]/a').click()
time.sleep(2)

for i in range(1,3):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

#For 4 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[2]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,3):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

#For 3 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[3]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,3):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 2 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[4]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,3):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 1 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[5]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,3):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

# %%
for i in URL2:
    driver.get(i)
    time.sleep(2)
    
    #comments
    c = driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']")
    Comments.append(c.text)
    
    #Ratings
    r = driver.find_element_by_xpath("//span[@class='a-size-medium a-color-base']").get_attribute('innerHTML').split(' ')[0]
    Ratings.append(r)

# %%
#For other Product
driver.get('https://www.amazon.in/Whirlpool-Refrigerator-WDE-205-CLS/dp/B083KW4D6D/ref=sr_1_1?crid=15667WZPMSK2W&keywords=refrigerator%2Bsingle%2Bdoor%2Blow%2Bprice&qid=1636638053&sprefix=refr%2Caps%2C412&sr=8-1&th=1')
time.sleep(5)

#Going into the reviews page
driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[5]/div[37]/div/div[2]/div/div[2]/span[3]/div/div/div[5]/div[2]/a").click()

# %%
URL2 = []

# For 5 Stars
driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[1]/td[1]/span[1]/a').click()
time.sleep(2)

for i in range(1,4):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

#For 4 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[2]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,4):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

#For 3 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[3]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,4):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 2 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[4]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,4):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 1 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[5]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,4):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

# %%
for i in URL2:
    driver.get(i)
    time.sleep(2)
    
    #comments
    c = driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']")
    Comments.append(c.text)
    
    #Ratings
    r = driver.find_element_by_xpath("//span[@class='a-size-medium a-color-base']").get_attribute('innerHTML').split(' ')[0]
    Ratings.append(r)

# %%
#For other Product
driver.get('https://www.amazon.in/Lenovo-Tab-M10-FHD-Plus/dp/B08BZSR4TX/ref=lp_4363894031_1_1')
time.sleep(5)

#Going into the reviews page
driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[5]/div[38]/div/div/div[2]/div/div[2]/span[3]/div/div/div[5]/div[2]/a").click()

# %%
URL2 = []

# For 5 Stars
driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[1]/td[1]/span[1]/a').click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

#For 4 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[2]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

#For 3 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[3]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 2 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[4]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 1 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[5]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

# %%
for i in URL2:
    driver.get(i)
    time.sleep(2)
    
    #comments
    c = driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']")
    Comments.append(c.text)
    
    #Ratings
    r = driver.find_element_by_xpath("//span[@class='a-size-medium a-color-base']").get_attribute('innerHTML').split(' ')[0]
    Ratings.append(r)

# %%
#For other Product
driver.get('https://www.amazon.in/gp/product/B08HMZ4J7Q/ref=s9_acss_bw_cg_revamp1_5a1_w?pf_rd_m=A1K21FY43GMZF8&pf_rd_s=merchandised-search-4&pf_rd_r=JKJDPHNXHXC2PMTQ0S8R&pf_rd_t=101&pf_rd_p=6e6c4f98-ae91-4d5c-bc4e-0d100ea828b7&pf_rd_i=13773797031')
time.sleep(5)

#Going into the reviews page
driver.find_element_by_xpath("/html/body/div[4]/div[3]/div[4]/div[325]/div/div[2]/div/div[2]/span[3]/div/div/div[5]/div[2]/a").click()

# %%
URL2 = []

# For 5 Stars
driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[1]/td[1]/span[1]/a').click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

#For 4 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[2]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

#For 3 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[3]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 2 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[4]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 1 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[5]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

# %%
for i in URL2:
    driver.get(i)
    time.sleep(2)
    
    #comments
    c = driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']")
    Comments.append(c.text)
    
    #Ratings
    r = driver.find_element_by_xpath("//span[@class='a-size-medium a-color-base']").get_attribute('innerHTML').split(' ')[0]
    Ratings.append(r)

# %%
#For other Product
driver.get('https://www.amazon.in/JBL-C50HI-Ear-Headphones-Blue/dp/B07JQKR35P/ref=sr_1_13?crid=1FUVZIJU3HVWM&keywords=headphones%2Bwith%2Bmic&qid=1636643798&s=electronics&sprefix=head%2Celectronics%2C396&sr=1-13&th=1')
time.sleep(5)

#Going into the reviews page
driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[5]/div[38]/div/div/div[2]/div/div[2]/span[4]/span/div[2]/div/div/div[6]/a").click()

# %%
URL2 = []

# For 5 Stars
driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[1]/td[1]/span[1]/a').click()
time.sleep(2)

for i in range(1,8):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

#For 4 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[2]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,8):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

#For 3 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[3]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,8):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 2 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[4]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,8):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 1 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[5]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,8):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 469

# %%
for i in URL2:
    driver.get(i)
    time.sleep(2)
    
    #comments
    c = driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']")
    Comments.append(c.text)
    
    #Ratings
    r = driver.find_element_by_xpath("//span[@class='a-size-medium a-color-base']").get_attribute('innerHTML').split(' ')[0]
    Ratings.append(r)

# %%
#For other Product
driver.get('https://www.amazon.in/Samsung-Fully-Automatic-WA65A4002VS-TL-Technology/dp/B08GY3PZQF/ref=sr_1_5?keywords=washing+machine&qid=1636645411&sr=8-5')
time.sleep(5)

#Going into the reviews page
driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[5]/div[27]/div/div[2]/div/div[2]/span[3]/div/div/div[5]/div[2]/a").click()

# %%
URL2 = []

# For 5 Stars
driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[1]/td[1]/span[1]/a').click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

#For 4 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[2]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

#For 3 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[3]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 2 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[4]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)
    
#For 1 Stars rating

driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[1]/div[1]/div/div[1]/div[4]/div/span/table[2]/tbody/tr[5]/td[1]/span[1]/a").click()
time.sleep(2)

for i in range(1,6):
    
    u = driver.find_elements_by_xpath("//a[@class = 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
    
    for i in u:
        URL2.append(i.get_attribute("href"))
        
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div/div[1]/div[5]/div[3]/div/div[12]/span/div/ul/li[2]/a').click()
    
    time.sleep(2)

# %%
for i in URL2:
    driver.get(i)
    time.sleep(2)
    
    #comments
    c = driver.find_element_by_xpath("//span[@class='a-size-base review-text review-text-content']")
    Comments.append(c.text)
    
    #Ratings
    r = driver.find_element_by_xpath("//span[@class='a-size-medium a-color-base']").get_attribute('innerHTML').split(' ')[0]
    Ratings.append(r)

# %%
data = list(zip(Comments, Ratings))

# %%
Ratings = pd.DataFrame(data=data,columns=['Comments','Ratings'])

Ratings.to_csv('Ratings.csv')
